# %%
import pandas as pa

# %%
birds = pa.read_csv("https://raw.githubusercontent.com/rain-ind/AP19110010495-B-Raja-Nithin/main/APSSDC%20Task%2013%20date%2023-6-21/bird.csv")
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
birds.sample(n=5)
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 57    57  250.00  11.91  252.00   8.31  73.04  7.37  160.00  8.47  82.46
# 199  199   32.68   3.26   29.02   2.36  39.38  2.72   56.45  2.50  32.56
# 191  191   32.34   3.17   29.05   2.36  39.64  2.70   55.36  2.51  37.08
# 190  190   32.02   2.99   27.70   2.38  38.27  2.64   53.33  2.71  31.00
# 135  135   45.68   3.95   38.98   3.51  29.15  2.44   45.23  2.52  24.64
#
#      tarw type
# 57   7.04   SW
# 199  2.49    T
# 191  2.22    T
# 190  2.45    T
# 135  2.64    W

# %%
birds.count()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# type     420
# dtype: int64

# %%
len(birds.columns)
# Out:
# 12

# %%
birds.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
birds.columns[10]
# Out:
# 'tarw'

# %%
birds.huml.dtypes
# Out:
# dtype('float64')

# %%
birds.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %%
birds.set_index("type", inplace = True)
birds
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 11 columns]

# %%
birds["huml"]
# Out:
# type
# SW    80.78
# SW    88.91
# SW    79.97
# SW    77.65
# SW    62.80
#       ...
# SO    17.96
# SO    19.21
# SO    18.79
# SO    20.38
# SO    17.89
# Name: huml, Length: 420, dtype: float64

# %%
birds.iloc[[3,4,5,6,7],:]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW     3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW     4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# SW     5  61.92  4.78  50.46   3.47  49.52  4.41  56.95  2.73  29.07  2.83
# SW     6  79.73  5.94  67.39   4.50  42.07  3.41  71.26  3.56  37.22  3.64
# SW     7  86.98  5.68  74.52   4.55  44.46  3.78  76.02  3.81  37.94  3.81

# %%
birds.loc[:,'humw':'feml']
# Out:
#       humw  ulnal  ulnaw   feml
# type
# SW    6.68  72.01   4.88  41.81
# SW    6.63  80.53   5.59  47.04
# SW    6.37  69.26   5.28  43.07
# SW    5.70  65.76   4.77  40.04
# SW    4.84  52.09   3.73  33.95
# ...    ...    ...    ...    ...
# SO    1.63  19.25   1.33  18.36
# SO    1.64  20.76   1.49  19.24
# SO    1.63  19.83   1.53  20.96
# SO    1.78  22.53   1.50  21.35
# SO    1.44  19.26   1.10  17.62
#
# [420 rows x 4 columns]

# %%
birds[birds['femw'] > 5.2]
birds[birds['femw'] < 10.5]
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [418 rows x 11 columns]

# %%
birds.iloc[2,9]
# Out:
# 38.31

# %%
birds.isna().sum().sum()
# Out:
# 15

# %%
birds["tibl"].mean()
# Out:
# 64.66282296650718

# %%
birds["tibl"].median()
# Out:
# 52.120000000000005

# %%
birds["tibw"].mean()
# Out:
# 3.1823389021479733

# %%
birds["tibw"].median()
# Out:
# 2.49

# %%
birds.groupby("ulnaw").mean()
# Out:
#           id        huml       humw       ulnal    feml  femw        tibl  \
# ulnaw
# 1.00   369.0   13.480000   1.270000   16.000000   12.67  1.10   23.120000
# 1.03   413.0   12.950000   1.160000   14.090000   13.03  1.03   22.130000
# 1.06   392.0   14.186667   1.203333   16.736667   13.94  1.03   24.743333
# 1.07   376.0   13.520000   1.280000   17.880000   15.10  1.05   25.140000
# 1.08   371.0   13.670000   1.270000   17.520000   12.77  1.16   25.470000
# ...      ...         ...        ...         ...     ...   ...         ...
# 10.42   38.0  272.000000  14.860000  320.000000   91.60  9.71  132.000000
# 10.74   33.0  210.000000  13.030000  278.000000   56.87  8.03   76.660000
# 10.90   39.0  270.000000  14.250000  310.000000   86.20  9.96  125.760000
# 11.72   58.0  420.000000  17.840000  422.000000  110.54  9.99  237.000000
# 12.00  174.0   71.350000   4.890000   80.970000   42.48  3.21   86.600000
#
#         tibw    tarl   tarw
# ulnaw
# 1.00    0.88   16.34   0.89
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
birds[['huml', 'humw', 'ulnal', 'feml', 'femw', 'tibl', 'tibw', 'tarl', 'tarw',]].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
